# %% [markdown]
# # Bài 1
# ![image.png](attachment:image.png)

# %%
diem_toan = 8
diem_ly = 9
diem_hoa = 8.5
c = ( diem_toan + diem_ly + diem_hoa ) / 3
print(c)
# Out:
# 8.5

# %%
c >= 8
# Out:
# True

# %%
c < 6
# Out:
# False

# %%
c >= 6 and c < 8
# Out:
# False

# %%
c = ( diem_toan + diem_ly + diem_hoa ) / 3

# %% [markdown]
# # Bài 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ti le tham gia lop hoc = a
# ti le hoan thanh trên trang learn = b
# diem thi cuoi khoa hoc = c

# %%
a = 0.8
b = 0.85
c = 8
print(a)
print(b)
print(c)
a > 0.75 and b > 0.8 and c >= 7.5
# Out:
# 0.8
# 0.85
# 8
# True

# %%
a > 0.75 and b > 0.8 and c >= 7.5
# Out:
# True

# %% [markdown]
# # bài 5
# ![image.png](attachment:image.png)

# %%
van_toc_xe_may = 36
van_toc_xe_dap = 12
quang_duong_hai_xe_cach_nhau = 48
hieu_van_toc = 36 - 12

thoi_gian_hai_xe_gap_nhau = quang_duong_hai_xe_cach_nhau / hieu_van_toc
print(thoi_gian_hai_xe_gap_nhau)
# Out:
# 2.0

# %% [markdown]
# # Bài 4
